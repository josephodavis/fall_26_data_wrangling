# %%
import re
import numpy as np
import pandas as pd

raw = pd.read_csv('week01_customers.csv', dtype=str)

NULL_TOKENS = ["NaN", "unknown", "-"]

CITY_ALIASES = {
    "nyc": "New York",
    "new york city": "New York",
}

DATE_FORMATS = [
    "%Y-%m-%d",
    "%m/%d/%Y",
    "%b %d %Y",
]

EMAIL_RE = re.compile(r"^[^@\s]+@[^@\s]+\.[A-Za-z]{2,}$")

# %% [markdown]
# # Part 1
#
# ### Task 1
# Every column is an object because they are either all strings or mixed datatypes.
# Age should be numeric, but some people have spelled out their age, making it a string
# Price should be numeric, but sometimes there is a $ in front of price
#
# ### Task 2
# df.isna().sum() does not give the full picture, because some values are not usable, yet do not show up through the command
#
# ### Task 3
# C-1005 and C-1013 are repeated. They are completely the same for every value
#
# ### Task 4
# Naive counts shown in the last cell
# Real counts:
# Boston      12
# Chicago     11
# Seattle     11
# Atlanta     10
# New York     13

# %%
print(raw.shape)
print("-")
print(raw.dtypes)
print("-")
print(raw.isna().sum())
# Out:
# (57, 8)
# -
# customer_id    object
# name           object
# age            object
# city           object
# signup_date    object
# price          object
# email          object
# membership     object
# dtype: object
# -
# customer_id    0
# name           0
# age            5
# city           0
# signup_date    0
# price          4
# email          4
# membership     0
# dtype: int64

# %%
print(raw)
# Out:
#    customer_id             name        age      city  signup_date      price  \
# 0       C-1001        Ann Smith         25  New York   2026-01-15  $1,299.00
# 1       C-1002      Brian Ochoa     thirty    Boston   2026-01-17      45.50
# 2       C-1003      Carla Reyes         41   Chicago   2026-01-19     230.00
# 3       C-1004        Devon Lee        NaN    Boston   2026-01-21     $89.99
# 4       C-1005       Elena Ford         34  new york   2026-01-22   1,050.00
# 5       C-1006     Frank Nguyen         28   Chicago   01/23/2026      62.75
# 6       C-1007    Grace Adeyemi        NaN   Seattle   2026-01-25     310.20
# 7       C-1008      Hector Diaz         52   Boston    2026-01-26  USD 75.00
# 8       C-1009     Imani Brooks  forty-two   Atlanta   2026-01-28  $2,480.00
# 9       C-1010      Jonas Weber         39   Seattle   2026-01-29      18.00
# 10      C-1011    Keisha Palmer         31   Atlanta   2026-02-01        NaN
# 11      C-1012   Luis Marchetti         -3   Chicago   2026-02-02     144.10
# 12      C-1013      Mona Haddad         27       NYC   2026-02-03    $540.00
# 13      C-1014         Noah Kim         45    Boston   2026-02-05        NaN
# 14      C-1015    Olivia Santos        999   Seattle   2026-02-06      76.40
# 15      C-1016      Peter Owusu         36   Atlanta   Feb 7 2026   1,875.25
# 16      C-1017   Quinn Baptiste         22   Chicago   2026-02-09     $33.00
# 17      C-1018     Rosa Delgado         58  new york   2026-02-10     410.00
# 18      C-1019    Samuel Achebe       29.0    Boston   2026-02-11      95.60
# 19      C-1020   Tara Whitfield         47   Seattle   2026-02-12  $1,120.00
# 20      C-1021       Umar Sesay         33   Atlanta   2026-02-14      58.85
# 21      C-1022   Vera Lindqvist    unknown   Chicago   2026-02-15     267.30
# 22      C-1023      Wesley Tran         40  NEW YORK   2026-02-16    $720.00
# 23      C-1024     Xiomara Peña         26    Boston   2026-02-18      49.99
# 24      C-1025      Yusuf Bello         61   Seattle   2026-02-19   1,340.75
# 25      C-1026    Zara Mitchell         35   Atlanta   2026-02-20    $210.00
# 26      C-1027       Aaron Cole        NaN   Chicago   2026-02-22      88.20
# 27      C-1028     Bianca Rossi         38  new york   2026-02-23     615.40
# 28      C-1029    Caleb Johnson         24    Boston   02/24/2026     $27.50
# 29      C-1030     Dalia Farouk         50   Seattle   2026-02-25     980.00
# 30      C-1031      Emeka Nwosu         43   Atlanta   2026-02-26     132.65
# 31      C-1032       Farah Aziz     twenty   Chicago   2026-02-27    $455.00
# 32      C-1033   Gabriel Moreau         37       NYC   2026-03-01      70.10
# 33      C-1034      Hannah Osei         30    Boston   2026-03-02        NaN
# 34      C-1035    Ibrahim Toure         55   Seattle   2026-03-03   1,690.00
# 35      C-1036   Julia Kaminski         23   Atlanta   2026-03-05     $41.25
# 36      C-1037    Kwame Boateng         46   Chicago   2026-03-06     525.90
# 37      C-1038      Lena Petrov        NaN  new york   2026-03-07     163.00
# 38      C-1039      Marcus Hill         32    Boston   2026-03-09  $2,015.00
# 39      C-1040  Nadia Chowdhury         48   Seattle   2026-03-10      84.45
# 40      C-1041      Omar Haddad         21   Atlanta   2026-03-11          -
# 41      C-1042      Priya Raman         44   Chicago   2026-03-12     377.80
# 42      C-1043   Quentin Dubois         57  NEW YORK   2026-03-13     $66.00
# 43      C-1044     Rachel Amoah         29    Boston  Mar 15 2026   1,208.55
# 44      C-1045    Silas Berhane         42   Seattle   2026-03-16     199.99
# 45      C-1046     Tamara Novak        NaN   Atlanta   2026-03-17      53.30
# 46      C-1047      Uche Okafor         51   Chicago   2026-03-18    $845.00
# 47      C-1048     Valeria Cruz         26  new york   2026-03-19     112.70
# 48      C-1049    Wanjiru Kamau         39    Boston   2026-03-20     690.00
# 49      C-1050     Xander Ellis      sixty   Seattle   2026-03-22     $38.40
# 50      C-1051     Yara Mansour         34   Atlanta   2026-03-23   1,455.00
# 51      C-1052     Zeke Alvarez         49   Chicago   2026-03-24     247.15
# 52      C-1053     Amara Diallo         27       NYC   2026-03-25        NaN
# 53      C-1054     Ben Kowalski         53    Boston   2026-03-26    $903.60
# 54      C-1055        Chidi Eze         31   Seattle   2026-03-27      74.80
# 55      C-1005       Elena Ford         34  new york   2026-01-22   1,050.00
# 56      C-1013      Mona Haddad         27       NYC   2026-02-03    $540.00
#
#                     email membership
# 0   ann.smith@example.com       gold
# 1     b.ochoa@example.com     silver
# 2     carla.r@example.com       gold
# 3   devon.lee@example.com     bronze
# 4      e.ford@example.com       gold
# 5                     NaN     silver
# 6     grace.a@example.com     bronze
# 7    hector.d@example.com     silver
# 8     imani.b@example.com       gold
# 9     jonas.w@example.com     bronze
# 10   keisha.p@example.com     silver
# 11     luis.m@example.com     bronze
# 12     mona.h@example.com       gold
# 13   noah.kim@example.com     silver
# 14   olivia.s@example.com     bronze
# 15    peter.o@example.com       gold
# 16                    NaN     bronze
# 17     rosa.d@example.com     silver
# 18      sam.a@example.com     bronze
# 19     tara.w@example.com       gold
# 20     umar.s@example.com     silver
# 21     vera.l@example.com     bronze
# 22   wes.tran@example.com       gold
# 23      xio.p@example.com     bronze
# 24    yusuf.b@example.com       gold
# 25                    NaN     silver
# 26    aaron.c@example.com     bronze
# 27   bianca.r@example.com       gold
# 28    caleb.j@example.com     bronze
# 29    dalia.f@example.com     silver
# 30    emeka.n@example.com     bronze
# 31    farah.a@example.com       gold
# 32  gabriel.m@example.com     silver
# 33   hannah.o@example.com     bronze
# 34  ibrahim.t@example.com       gold
# 35    julia.k@example.com     bronze
# 36    kwame.b@example.com     silver
# 37     lena.p@example.com     bronze
# 38   marcus.h@example.com       gold
# 39    nadia.c@example.com     silver
# 40     omar.h@example.com     bronze
# 41    priya.r@example.com       gold
# 42                    NaN     silver
# 43   rachel.a@example.com       gold
# 44    silas.b@example.com     bronze
# 45   tamara.n@example.com     silver
# 46     uche.o@example.com       gold
# 47  valeria.c@example.com     bronze
# 48  wanjiru.k@example.com     silver
# 49   xander.e@example.com     bronze
# 50     yara.m@example.com       gold
# 51     zeke.a@example.com     silver
# 52    amara.d@example.com     bronze
# 53      ben.k@example.com       gold
# 54    chidi.e@example.com     bronze
# 55     e.ford@example.com       gold
# 56     mona.h@example.com       gold

# %%
print(len(raw))
print(raw['customer_id'].nunique())
print(raw['customer_id'].duplicated(keep=False))
# Out:
# 57
# 55
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55     True
# 56     True
# Name: customer_id, dtype: bool

# %%
print(raw["city"].value_counts())
# Out:
# Boston      11
# Chicago     11
# Seattle     11
# Atlanta     10
# new york     6
# NYC          4
# NEW YORK     2
# New York     1
#  Boston      1
# Name: city, dtype: int64

# %% [markdown]
# # Part 2
#
# ### Task 5
# I included NaN, unknown, and -, because they are the tokens that represent an unknown value in this dataset
#
# ### Task 6
# a) None are UNUSABLE, but some are null / NaN (5)
# b) C-1041
# c) There will be many different types of unusable numbers, you must take into account a wide range
#
# ### Task 7
# a) Easier to understand / consolidate
# b) The naive call discarded null values
# c) Between 16 and 100 because a person cannot physically buy things outside of this range
# d) The mean before my range was much larger because of the 999 outlier
#
# ### Task 8
# Final counts same as before, .str.title is insufficient because it does not take into account apostrophes and other particularities.
#
# ### Task 9
# There is YYYY-MM-DD, MM/DD/YYYY, and MM DD YYYY.
# 01/23/2026 is unambiguous because the beginning month can only be a month not a day, since 23 cannot be a month
#
# ### Task 10
# 4 addresses are missing (C-1006, C-1017, C-1026, C-1043). Of the 53 present, all 53 pass the regex.
# Gabriel Garcia Marquez breaks because it is 3 parts
# Mao Zedong breaks because family name comes first

# %%
def to_null(value):
    
    if value in NULL_TOKENS:
        return np.nan
    if isinstance(value, str):
        value.strip()
        
    return value

def clean_price(value):
    if isinstance(value, str):
        value = value.strip()
        value = value.strip("$")
        value = value.strip("USD")
        value = value.replace(",", "")
        value = float(value)
    
    return value

def clean_age(value):
    value = float(value)
    return value

def validate_age(value):
    value = to_null(value)
    if value < 16 or value > 100:
        value = np.nan
    
    return value

# Claude Used
def clean_city(value):
    value = to_null(value)
    if not isinstance(value, str):
        return value

    value = value.strip()
    value = re.sub(r"\s+", " ", value)

    key = value.lower()
    if key in CITY_ALIASES:
        return CITY_ALIASES[key]

    return value.title()

# Claude Used
def clean_date(value):
    value = to_null(value)
    if not isinstance(value, str):
        return pd.NaT

    value = value.strip()
    value = re.sub(r"\s+", " ", value)

    for fmt in DATE_FORMATS:
        try:
            return pd.to_datetime(value, format=fmt)
        except ValueError:
            pass

    return pd.NaT

# Claude Used
def valid_email(value):
    value = to_null(value)
    if not isinstance(value, str):
        return False

    return EMAIL_RE.match(value.strip()) is not None

# %%
# email validity
raw["email_valid"] = raw["email"].map(valid_email)

present = raw["email"].notna()
print("missing emails:", int((~present).sum()))
print("present emails:", int(present.sum()))
print("present and passing:", int((present & raw["email_valid"]).sum()))
print("present and failing:", int((present & ~raw["email_valid"]).sum()))

# split name into first / last
n_parts = raw["name"].str.strip().str.split(r"\s+", regex=True).str.len()
print("every row splits into exactly two parts:", bool(n_parts.eq(2).all()))
print(n_parts.value_counts())

parts = raw["name"].str.strip().str.split(r"\s+", expand=True, regex=True)
raw["first_name"] = parts[0]
raw["last_name"] = parts[1]

print(raw[["name", "first_name", "last_name", "email", "email_valid"]].head())
# Out:
# missing emails: 4
# present emails: 53
# present and passing: 53
# present and failing: 0
# every row splits into exactly two parts: True
# 2    57
# Name: name, dtype: int64
#           name first_name last_name                  email  email_valid
# 0    Ann Smith        Ann     Smith  ann.smith@example.com         True
# 1  Brian Ochoa      Brian     Ochoa    b.ochoa@example.com         True
# 2  Carla Reyes      Carla     Reyes    carla.r@example.com         True
# 3    Devon Lee      Devon       Lee  devon.lee@example.com         True
# 4   Elena Ford      Elena      Ford     e.ford@example.com         True

# %% [markdown]
# ## Part 3
